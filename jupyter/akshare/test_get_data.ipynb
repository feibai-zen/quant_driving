# %%
import akshare as ak

print(ak.__version__)
# Out:
# 1.16.86

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20170301", end_date='20231022', adjust="")
print(stock_zh_a_hist_df)
# Out:
#               日期    股票代码     开盘     收盘     最高     最低      成交量           成交额  \
# 0     2017-03-01  000001   9.49   9.49   9.55   9.47   346994  3.301580e+08
# 1     2017-03-02  000001   9.51   9.43   9.54   9.42   403629  3.823959e+08
# 2     2017-03-03  000001   9.41   9.40   9.43   9.36   342655  3.219525e+08
# 3     2017-03-06  000001   9.40   9.45   9.46   9.39   404511  3.812123e+08
# 4     2017-03-07  000001   9.44   9.45   9.46   9.40   294673  2.777474e+08
# ...          ...     ...    ...    ...    ...    ...      ...           ...
# 1610  2023-10-16  000001  11.00  11.01  11.03  10.95   501624  5.509887e+08
# 1611  2023-10-17  000001  11.01  11.02  11.05  10.96   493525  5.431709e+08
# 1612  2023-10-18  000001  10.99  10.95  11.02  10.91   651825  7.139799e+08
# 1613  2023-10-19  000001  10.91  10.60  10.92  10.59  1188961  1.271915e+09
# 1614  2023-10-20  000001  10.55  10.60  10.67  10.51   526139  5.576186e+08
#
#         振幅   涨跌幅   涨跌额   换手率
# 0     0.84  0.11  0.01  0.21
# 1     1.26 -0.63 -0.06  0.24
# 2     0.74 -0.32 -0.03  0.20
# 3     0.74  0.53  0.05  0.24
# 4     0.63  0.00  0.00  0.17
# ...    ...   ...   ...   ...
# 1610  0.73  0.09  0.01  0.26
# 1611  0.82  0.09  0.01  0.25
# 1612  1.00 -0.64 -0.07  0.34
# 1613  3.01 -3.20 -0.35  0.61
# 1614  1.51  0.00  0.00  0.27
#
# [1615 rows x 12 columns]

# %%
stock_zh_a_hist_df.head()
# Out:
#            日期    股票代码    开盘    收盘    最高    最低     成交量          成交额    振幅  \
# 0  2017-03-01  000001  9.49  9.49  9.55  9.47  346994  330157968.0  0.84
# 1  2017-03-02  000001  9.51  9.43  9.54  9.42  403629  382395888.0  1.26
# 2  2017-03-03  000001  9.41  9.40  9.43  9.36  342655  321952544.0  0.74
# 3  2017-03-06  000001  9.40  9.45  9.46  9.39  404511  381212304.0  0.74
# 4  2017-03-07  000001  9.44  9.45  9.46  9.40  294673  277747408.0  0.63
#
#     涨跌幅   涨跌额   换手率
# 0  0.11  0.01  0.21
# 1 -0.63 -0.06  0.24
# 2 -0.32 -0.03  0.20
# 3  0.53  0.05  0.24
# 4  0.00  0.00  0.17

# %%
stock_zh_a_hist_df.tail()
# Out:
#               日期    股票代码     开盘     收盘     最高     最低      成交量           成交额  \
# 1610  2023-10-16  000001  11.00  11.01  11.03  10.95   501624  5.509887e+08
# 1611  2023-10-17  000001  11.01  11.02  11.05  10.96   493525  5.431709e+08
# 1612  2023-10-18  000001  10.99  10.95  11.02  10.91   651825  7.139799e+08
# 1613  2023-10-19  000001  10.91  10.60  10.92  10.59  1188961  1.271915e+09
# 1614  2023-10-20  000001  10.55  10.60  10.67  10.51   526139  5.576186e+08
#
#         振幅   涨跌幅   涨跌额   换手率
# 1610  0.73  0.09  0.01  0.26
# 1611  0.82  0.09  0.01  0.25
# 1612  1.00 -0.64 -0.07  0.34
# 1613  3.01 -3.20 -0.35  0.61
# 1614  1.51  0.00  0.00  0.27

# %%
import akshare as ak
import mplfinance as mpf  # Please install mplfinance as follows: pip install mplfinance

stock_us_daily_df = ak.stock_us_daily(symbol="AAPL", adjust="qfq")
stock_us_daily_df = stock_us_daily_df.set_index(["date"])
stock_us_daily_df = stock_us_daily_df["2020-04-01": "2020-04-29"]
mpf.plot(stock_us_daily_df, type="candle", mav=(3, 6, 9), volume=True, show_nontrading=False)

# %%
# !pip install mplfinance
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting mplfinance
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d7/d9/31c436ea7673c21a5bf3fc747bc7f63377582dfe845c3004d3e46f9deee0/mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 165.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from mplfinance) (3.5.2)
# Requirement already satisfied: pandas in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from mplfinance) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mplfinance) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from pandas->mplfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/yuanlongli/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0
