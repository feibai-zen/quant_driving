# %%
import akshare as ak

stock_hk_hist_min_em_df = ak.stock_hk_hist_min_em(symbol="01918", period='30', adjust='',
                                                  start_date="2025-04-01 09:32:00",
                                                  end_date="2025-05-07 18:32:00")  # 其中的 start_date 和 end_date 需要设定为近期
print(stock_hk_hist_min_em_df)

# print(stock_hk_hist_min_em_df['时间'],stock_hk_hist_min_em_df['成交量'])
# Out:
#                       时间    开盘    收盘    最高    最低   涨跌幅   涨跌额       成交量  \
# 0    2025-04-01 10:00:00  1.57  1.57  1.58  1.55  1.29  0.02  13036000
# 1    2025-04-01 10:30:00  1.57  1.56  1.58  1.55 -0.64 -0.01   7655000
# 2    2025-04-01 11:00:00  1.55  1.54  1.56  1.54 -1.28 -0.02   6355000
# 3    2025-04-01 11:30:00  1.54  1.56  1.56  1.54  1.30  0.02   4635000
# 4    2025-04-01 12:00:00  1.56  1.55  1.56  1.55 -0.64 -0.01   2628000
# ..                   ...   ...   ...   ...   ...   ...   ...       ...
# 215  2025-05-02 14:00:00  1.50  1.51  1.51  1.50  0.67  0.01    460000
# 216  2025-05-02 14:30:00  1.51  1.51  1.51  1.50  0.00  0.00   2297000
# 217  2025-05-02 15:00:00  1.50  1.51  1.51  1.50  0.00  0.00    607000
# 218  2025-05-02 15:30:00  1.50  1.50  1.51  1.49 -0.66 -0.01   1565000
# 219  2025-05-02 16:00:00  1.50  1.50  1.50  1.49  0.00  0.00   5949000
#
#             成交额    振幅   换手率
# 0    20449010.0  1.94  0.12
# 1    11973030.0  1.91  0.07
# ...

# %%
import akshare as ak

stock_news_main_cx_df = ak.stock_news_main_cx()


print(stock_news_main_cx_df.head(20).get(1))
# Out:
# None

# %%
import akshare as ak

stock_hk_hist_df = ak.stock_hk_hist(symbol="01918", period="daily", start_date="19700101", end_date="22220101", adjust="")
print(stock_hk_hist_df)
# Out:
#               日期    开盘    收盘    最高    最低         成交量           成交额     振幅  \
# 0     2010-10-07  3.50  3.38  3.53  3.20   245817000  8.349440e+08   9.48
# 1     2010-10-08  3.30  3.25  3.32  3.17    35386300  1.144020e+08   4.44
# 2     2010-10-11  3.23  3.04  3.25  3.02    31954000  9.849650e+07   7.08
# 3     2010-10-12  3.03  2.89  3.05  2.82    59327000  1.715220e+08   7.57
# 4     2010-10-13  2.88  3.16  3.17  2.88    71370000  2.218510e+08  10.03
# ...          ...   ...   ...   ...   ...         ...           ...    ...
# 3295  2025-04-25  1.68  1.55  1.83  1.54  1379772256  2.322605e+09  17.47
# 3296  2025-04-28  1.58  1.51  1.59  1.48   197513400  3.012604e+08   7.10
# 3297  2025-04-29  1.52  1.50  1.55  1.50   135935769  2.069065e+08   3.31
# 3298  2025-04-30  1.51  1.50  1.52  1.45   250350073  3.718029e+08   4.67
# 3299  2025-05-02  1.51  1.50  1.52  1.49    30436882  4.576647e+07   2.00
#
#        涨跌幅   涨跌额    换手率
# 0    -2.87 -0.10   8.19
# 1    -3.85 -0.13   1.18
# ...
